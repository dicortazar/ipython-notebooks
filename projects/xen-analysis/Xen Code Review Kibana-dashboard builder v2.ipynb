# %% [markdown]
# Case of study: Developers
#
# This will provide an index full of information for each developer.
#
# The goal is to have a full idea of how developers and organizations (per domain initially) deal with the concept of review, to award top ones if required, to avoid not that useful noise after an ack and to notice those more focused on reviewing activities or in development of new functionalities.
#
# Each row is based on the following fields:
#  * EmailType: 'patch serie', 'patch', 'review' or 'comment'
#  * Developer: email of the developer
#  * Domain: domain of the developer
#  * Time: time when the email was sent
#  * Balance: this contains a -1 if this is patch and a +1 if this is a review. Any other 'EmailTYpe' contains a 0
#  * Subject: subject of the email
#  * Flag: for 'review' or 'comment' 'EmailType', this contains the specific flag used by the developer if so: eg-'Reviewed-by', etc.
#  * Merged: this contains a +1 if this was merged. 0 In any other case.
#  * MergeTime: this contains info if the field 'Merged' is +1.
#  * PostAck: this contains a +1 if the 'EmailType' is 'comment' or 'review', that patch was merged and this comment or review was done after a previous review with the flag 'acked-by'
#
# This is intended to build the following tables:
#  * Top reviewers by developer and top reviewers by domain: No. reviews, No. patches, No. patch series
#  * Imbalances by developer and by domain: this is an integer providing negative or positive values. The more the negative, the more patches sent vs reviews done.
#  * Post ack by developer and by reviewer
#
# Also the following charts:
#  * Patch evolution
#  * Reviews evolution
#  * Comments evolution
#  * Patch series evolution
#
# And the following tables (searches in Kibana nomenclature) at the very end:
#  * Patches
#  * Comments
#  * Reviews

# %%
# Elastic search library
from elasticsearch import Elasticsearch, helpers
# python-mysql database access
import MySQLdb
import logging
import pandas

# %%
def connect():
   user = "root"
   password = ""
   host = "localhost"
   db = "xen_reports_patchsets_phase2_4"

   try:
      db = MySQLdb.connect(user = user, passwd = password, db = db, charset='utf8')
      return db, db.cursor()
   except:
      logging.error("Database connection error")
      raise
        


def execute_query(connector, query):
   results = int (connector.execute(query))
   cont = 0
   if results > 0:
      result1 = connector.fetchall()
      return result1
   else:
      return []
    

db, cursor = connect()

# %%
# Insert data in ElasticSearch
def to_json(row, columns):
    # Function that translates from tuple to JSON doc
    doc = {}
    
    for column in columns:
       
        value = row[columns.index(column) + 1] 
       
        try:
            doc[column] = value
        except:
            doc[column] = ""
   
    return doc

# %%
query_patchseries = """ SELECT ps.id as patchserie_id,
                                -1 as patch_id,
                                -1 as comment_id,
                                ps.subject as subject,
                                pe.email as sender,
                                SUBSTRING_INDEX(pe.email, '@', -1) as sender_domain,
                                MIN(psv.date_utc) as sent_date,
                                0 as balance,
                                'na' as flag,
                                IF(p.commit_id IS NULL, 0, 1) as merged,
                                'patchserie' as emailtype,
                                0 as num_flag_review,
                                0 as num_flag_ack,
                                0 as num_patches,
                                0 as is_acked,
                                0 as post_ack_comment
                         FROM  patch_series ps,
                               patch_series_version psv,
                               patches p,
                               people pe
                         WHERE pe.id = p.submitter_id AND
                               p.ps_version_id = psv.id AND
                               psv.ps_id = ps.id
                         GROUP BY ps.id """
                               
                         
query_patches = """ SELECT psv.ps_id as patchserie_id,
                           p.id as patch_id,
                           -1 as comment_id,
                           p.subject as subject,
                           pe.email as sender,
                           SUBSTRING_INDEX(pe.email, '@', -1) as sender_domain,
                           p.date_utc as sent_date,
                           1 as balance,
                           'na' as flag,
                           IF(p.commit_id IS NULL, 0, 1) as merged,
                           'patch' as emailtype,
                           0 as num_flag_review,
                           0 as num_flag_ack,
                           1 as num_patches,
                           IF(t.flag='Acked-by', 1, 0) as is_acked,
                           0 as post_ack_comment
                    FROM   patch_series_version psv,
                           patches p,
                           people pe,
                           (SELECT p.id as patch_id,
                                   f.flag as flag
                            FROM patches p
                            LEFT JOIN flags f
                            ON p.id = f.patch_id AND 
                               f.flag = 'Acked-by') t
                    WHERE p.submitter_id = pe.id AND
                          psv.id = p.ps_version_id AND
                          p.id = t.patch_id"""
                    
                           

query_flags = """ SELECT psv.ps_id as patchserie_id,
                         patch_id as patch_id,
                         -1 as comment_id,
                         p.subject as subject,
                         SUBSTRING_INDEX(SUBSTRING_INDEX(value, '<', -1), '>', 1) as sender,
                         SUBSTRING_INDEX(SUBSTRING_INDEX(SUBSTRING_INDEX(value, '<', -1), '>', 1), '@', -1) as sender_domain,
                         f.date_utc as sent_date,
                         IF(flag = 'Reviewed-by', -1, 0) as balance,
                         flag as flag,
                         0 as merged,
                         'flag' as emailtype,
                         IF(flag = 'Reviewed-by', 1, 0) as num_flag_review,
                         IF(flag = 'Acked-by', 1, 0) as num_flag_ack,
                         0 as num_patch,
                         0 as is_acked,
                         0 as post_ack_comment
                  FROM patch_series_version psv,
                       patches p,
                       flags f
                  WHERE psv.id = p.ps_version_id AND
                        p.id = f.patch_id
                 """

#If required, some example of filters by flag
#(flag = 'Reviewed-by' OR
# flag = 'Acked-by')


query_comments = """ SELECT psv.ps_id as patchserie_id,
                            c.patch_id as patch_id,
                            c.id as comment_id,
                            c.subject as subject,
                            pe.email as sender,
                            SUBSTRING_INDEX(pe.email, '@', -1) as sender_domain,
                            c.date_utc as sent_date,
                            0 as balance,
                            'na' as flag,
                            0 as merged,
                            'comment' as emailtype,
                            0 as num_flag_review,
                            0 as num_flag_ack,
                            0 as num_patch,
                            0 as is_acked,
                            0 as post_ack_comment
                     FROM patch_series_version psv,
                          patches p,
                          people pe,
                          comments c
                     WHERE psv.id = p.ps_version_id AND
                           p.id = c.patch_id AND
                           c.submitter_id = pe.id """
                            

# How to test post-ack comments:
# select comments.id, subject, date, first_ack_date, comments.patch_id 
# from comments, (select patch_id, min(date) as first_ack_date from flags where flag='Acked-by' group by patch_id) t 
# where date > t.first_ack_date and t.patch_id = comments.patch_id limit 100;

query_post_ack = """ SELECT comments.id as comment_id,
                            1 as post_ack_comment
                     FROM comments left join 
                              (SELECT patch_id,
                                      MIN(date) as first_ack_date 
                               FROM flags 
                               WHERE flag='Acked-by' 
                               GROUP BY patch_id) t 
                           ON t.patch_id=comments.patch_id 
                     WHERE date > t.first_ack_date """

# %%
data_patchseries = list(execute_query(cursor, query_patchseries))
data_patches = list(execute_query(cursor, query_patches))
data_flags = list(execute_query(cursor, query_flags))
data_comments = list(execute_query(cursor, query_comments))
data_post_ack = list(execute_query(cursor, query_post_ack))

# %%
columns = ["patchserie_id", "patch_id", "comment_id", "subject", "sender", "sender_domain", "sent_date", "balance", "flag", "merged", "emailtype", "num_flag_review", "num_flag_ack", "num_patch", "is_acked", "post_ack_comment"]

patchseries_df = pandas.DataFrame(data_patchseries, columns = columns)
patches_df = pandas.DataFrame(data_patches, columns = columns)
flags_df = pandas.DataFrame(data_flags, columns = columns)
comments_df = pandas.DataFrame(data_comments, columns=columns)
post_ack_df = pandas.DataFrame(data_post_ack, columns=["comment_id", "post_ack_comment"])

# %%
#Patching values coming from post_ack_df into comments_df dataframe
comments_df.update(post_ack_df)

# %%
#Checking if the previous line properly worked
comments_df[comments_df["post_ack_comment"]==1]
# Out:
#       patchserie_id  patch_id  comment_id  \
# 0                 1         1        1507
# 1                 1         4        1508
# 2                 1         4        1509
# 3                 1         4        1510
# 4                 1         4        2675
# 5                 1         4        2923
# 6                 1         4        2924
# 7                 1         4        2925
# 8                 1         4        2926
# 9                 1         4        2927
# 10                1         4        2928
# 11                1         5        3504
# 12                1         6        3505
# 13                1         7        3506
# 14                1         7        3507
# 15                1         8        3769
# 16                1         8        3770
# 17                5        13        3771
# 18                5        13        3772
# 19               15        23        3773
# 20               19        27        3915
# 21               22        30        3916
# 22               22        30        3917
# 23               22        30        3918
# 24               22        30        3919
# 25               22        30        3920
# 26               22        30        3922
# 27               22        30        3930
# 28               22        30        3968
# 29               24        32        3974
# ...             ...       ...         ...
# 9700           8246      8441       67998
# 9701           8246      8441       67999
# 9702           8246      8441       68063
# 9703           8246      8441       68064
# 9704           8246      8441       68088
# 9705           8246      8441       68103
# 9706           8246      8441       68104
# 9707           8246      8441       68124
# 9708           8246      8441       68141
# 9709           8246      8441       68142
# 9710           8246      8441       68143
# 9711           8246      8441       68146
# 9712           8246      8441       68148
# 9713           8246      8441       68149
# 9714           8246      8441       68154
# 9715           8246      8441       68194
# 9716           8246      8441       68196
# 9717           8246      8441       68212
# 9718           8246      8441       68213
# 9719           8252      8447       68220
# 9720           8253      8448       68223
# 9721           8254      8449       68227
# 9722           8254      8449       68228
# 9723           8256      8451       68229
# 9724           8256      8451       68230
# 9725           8256      8451       68231
# 9726           8256      8451       68232
# 9727           8256      8451       68233
# 9728           8256      8451       68235
# 9729           8256      8451       68244
#
#                                                 subject  \
# 0     Re: [PATCH v2 1/2] x86/hvm: Always do SMAP che...
# 1     Re: [PATCH v3 1/2] x86/hvm: Always do SMAP che...
# 2     Re: [PATCH v3 1/2] x86/hvm: Always do SMAP che...
# 3     Re: [PATCH v3 1/2] x86/hvm: Always do SMAP che...
# 4     Re: [PATCH v3 1/2] x86/hvm: Always do SMAP che...
# 5     Re: [PATCH v3 1/2] x86/hvm: Always do SMAP che...
# 6     Re: [PATCH v3 1/2] x86/hvm: Always do SMAP che...
# 7     Re: [PATCH v3 1/2] x86/hvm: Always do SMAP che...
# 8     Re: [PATCH v3 1/2] x86/hvm: Always do SMAP che...
# 9     Re: [PATCH v3 1/2] x86/hvm: Always do SMAP che...
# 10    Re: [PATCH v3 1/2] x86/hvm: Always do SMAP che...
# 11    Re: [PATCH v3 2/2] x86/hvm: Always do SMAP che...
# 12    Re: [PATCH v3 0/2] x86/HVM: Properly handle SM...
# 13    Re: [PATCH v4 0/2] x86/HVM: Properly handle SM...
# 14    Re: [PATCH v4 0/2] x86/HVM: Properly handle SM...
# 15    Re: [PATCH v4 1/2] x86/hvm: Always do SMAP che...
# 16    Re: [PATCH v4 1/2] x86/hvm: Always do SMAP che...
# 17    Re: [PATCH] Always call blkdev_put when destro...
# 18    Re: [PATCH] Always call blkdev_put when destro...
# 19    Re: [PATCH] domain.c idle_loop declaration (ta...
# 20    Re: [PATCH] X server crashes Xen on xeno-unsta...
# 21        Re: [PATCH] USB virtualisation (experimental)
# 22    [updated] Re: [PATCH] USB virtualisation (expe...
# 23    [updated] Re: [PATCH] USB virtualisation (expe...
# 24        Re: [PATCH] USB virtualisation (experimental)
# 25    Re: [updated] Re: [PATCH] USB virtualisation (...
# 26        Re: [PATCH] USB virtualisation (experimental)
# 27    Re: [updated] Re: [PATCH] USB virtualisation (...
# 28        Re: [PATCH] USB virtualisation (experimental)
# 29    Re: [PATCH] tools: surface smp guest cpu alloc...
# ...                                                 ...
# 9700  [PATCH 5/9] blkio-cgroup-v9: The body of blkio...
# 9701  [PATCH 3/9] blkio-cgroup-v9: The new page_cgro...
# 9702   [PATCH 7/9] blkio-cgroup-v9: Page tracking hooks
# 9703  [PATCH 3/9] blkio-cgroup-v9: The new page_cgro...
# 9704  [PATCH 3/9] blkio-cgroup-v9: The new page_cgro...
# 9705    [PATCH 8/9] blkio-cgroup-v9: Fast page tracking
# 9706   [PATCH 7/9] blkio-cgroup-v9: Page tracking hooks
# 9707  [PATCH 3/9] blkio-cgroup-v9: The new page_cgro...
# 9708  [PATCH 3/9] blkio-cgroup-v9: The new page_cgro...
# 9709  [PATCH 9/9] blkio-cgroup-v9: Add a cgroup supp...
# 9710   [PATCH 7/9] blkio-cgroup-v9: Page tracking hooks
# 9711   [PATCH 7/9] blkio-cgroup-v9: Page tracking hooks
# 9712  Re: [PATCH 7/9] blkio-cgroup-v9: Page tracking...
# 9713  Re: [PATCH 7/9] blkio-cgroup-v9: Page tracking...
# 9714  Re: [PATCH 7/9] blkio-cgroup-v9: Page tracking...
# 9715  Re: [PATCH 7/9] blkio-cgroup-v9: Page tracking...
# 9716  Re: [PATCH 7/9] blkio-cgroup-v9: Page tracking...
# 9717  Re: [PATCH 7/9] blkio-cgroup-v9: Page tracking...
# 9718  Re: [PATCH 7/9] blkio-cgroup-v9: Page tracking...
# 9719  Re: [PATCH] xend: Don't call decode() if PV_{k...
# 9720    [PATCH] hoplugpath.sh: fix Makefile dependency.
# 9721  Re: [PATCH] python: make tools/python/xen/util...
# 9722  Re: [PATCH] python: make tools/python/xen/util...
# 9723            [PATCH] tools: python portability fixes
# 9724            [PATCH] tools: python portability fixes
# 9725            [PATCH] tools: python portability fixes
# 9726            [PATCH] tools: python portability fixes
# 9727            [PATCH] tools: python portability fixes
# 9728            [PATCH] tools: python portability fixes
# 9729            [PATCH] tools: python portability fixes
#
#                               sender       sender_domain           sent_date  \
# 0                  JBeulich@suse.com            suse.com 2014-07-28 09:11:38
# 1                  JBeulich@suse.com            suse.com 2014-07-29 07:19:07
# 2                  feng.wu@intel.com           intel.com 2014-07-29 07:54:12
# 3                  feng.wu@intel.com           intel.com 2014-07-29 08:13:51
# 4                  JBeulich@suse.com            suse.com 2014-07-29 08:22:36
# 5                  JBeulich@suse.com            suse.com 2014-07-29 08:25:14
# 6                  feng.wu@intel.com           intel.com 2014-07-29 08:42:56
# 7                  feng.wu@intel.com           intel.com 2014-07-29 08:26:29
# 8                  JBeulich@suse.com            suse.com 2014-07-29 09:04:46
# 9                  feng.wu@intel.com           intel.com 2014-07-29 09:07:28
# 10                 JBeulich@suse.com            suse.com 2014-07-29 09:47:55
# 11                 JBeulich@suse.com            suse.com 2014-07-29 07:21:21
# 12                 feng.wu@intel.com           intel.com 2014-07-29 07:07:08
# 13              linux@eikelenboom.it      eikelenboom.it 2014-07-30 13:14:28
# 14                 feng.wu@intel.com           intel.com 2014-07-30 13:20:27
# 15                 JBeulich@suse.com            suse.com 2014-07-30 08:15:24
# 16                 feng.wu@intel.com           intel.com 2014-07-30 08:53:40
# 17    Christian.Limpach@cl.cam.ac.uk        cl.cam.ac.uk 2004-08-28 00:01:10
# 18              doogie@brainfood.com       brainfood.com 2004-08-28 02:18:57
# 19                 adam@cfar.umd.edu        cfar.umd.edu 2004-12-22 19:13:59
# 20                 adam@cfar.umd.edu        cfar.umd.edu 2005-01-06 22:25:23
# 21                    niv@us.ibm.com          us.ibm.com 2005-01-11 00:24:29
# 22      mark.williamson@cl.cam.ac.uk        cl.cam.ac.uk 2005-01-14 01:38:06
# 23      Mark.Williamson@cl.cam.ac.uk        cl.cam.ac.uk 2005-01-14 02:49:51
# 24      Mark.Williamson@cl.cam.ac.uk        cl.cam.ac.uk 2005-01-11 03:21:55
# 25              doogie@brainfood.com       brainfood.com 2005-01-14 18:59:51
# 26                  aquynh@gmail.com           gmail.com 2005-01-12 14:58:40
# 27      Mark.Williamson@cl.cam.ac.uk        cl.cam.ac.uk 2005-01-14 19:02:58
# 28      Mark.Williamson@cl.cam.ac.uk        cl.cam.ac.uk 2005-01-12 15:12:10
# 29    Christian.Limpach@cl.cam.ac.uk        cl.cam.ac.uk 2005-01-17 21:15:10
# ...                              ...                 ...                 ...
# 9700  kamezawa.hiroyu@jp.fujitsu.com      jp.fujitsu.com 2009-07-22 02:11:20
# 9701              ryov@valinux.co.jp       valinux.co.jp 2009-07-22 08:28:43
# 9702              ryov@valinux.co.jp       valinux.co.jp 2009-07-21 14:23:16
# 9703       balbir@linux.vnet.ibm.com  linux.vnet.ibm.com 2009-07-22 08:37:22
# 9704  kamezawa.hiroyu@jp.fujitsu.com      jp.fujitsu.com 2009-07-22 08:39:41
# 9705              ryov@valinux.co.jp       valinux.co.jp 2009-07-21 14:24:01
# 9706  kamezawa.hiroyu@jp.fujitsu.com      jp.fujitsu.com 2009-07-22 02:17:14
# 9707  kamezawa.hiroyu@jp.fujitsu.com      jp.fujitsu.com 2009-07-22 08:46:09
# 9708              ryov@valinux.co.jp       valinux.co.jp 2009-07-22 09:30:11
# 9709              ryov@valinux.co.jp       valinux.co.jp 2009-07-21 14:24:44
# 9710              ryov@valinux.co.jp       valinux.co.jp 2009-07-22 09:40:55
# 9711  kamezawa.hiroyu@jp.fujitsu.com      jp.fujitsu.com 2009-07-23 00:18:41
# 9712              ryov@valinux.co.jp       valinux.co.jp 2009-07-23 06:38:43
# 9713  kamezawa.hiroyu@jp.fujitsu.com      jp.fujitsu.com 2009-07-23 07:49:35
# 9714              ryov@valinux.co.jp       valinux.co.jp 2009-07-23 10:02:53
# 9715  kamezawa.hiroyu@jp.fujitsu.com      jp.fujitsu.com 2009-07-23 12:02:13
# 9716              ryov@valinux.co.jp       valinux.co.jp 2009-07-24 05:44:16
# 9717  kamezawa.hiroyu@jp.fujitsu.com      jp.fujitsu.com 2009-07-24 06:19:23
# 9718              ryov@valinux.co.jp       valinux.co.jp 2009-07-24 08:48:53
# 9719                xen@flonatel.org        flonatel.org 2009-07-26 20:51:20
# 9720         Christoph.Egger@amd.com             amd.com 2009-07-23 09:03:33
# 9721                xen@flonatel.org        flonatel.org 2009-07-26 21:07:29
# 9722          yamahata@valinux.co.jp       valinux.co.jp 2009-07-27 03:02:42
# 9723       keir.fraser@eu.citrix.com       eu.citrix.com 2009-07-23 14:06:25
# 9724       Ian.Jackson@eu.citrix.com       eu.citrix.com 2009-07-27 18:57:28
# 9725         Christoph.Egger@amd.com             amd.com 2009-07-28 07:34:42
# 9726       Ian.Jackson@eu.citrix.com       eu.citrix.com 2009-07-28 09:55:59
# 9727         Christoph.Egger@amd.com             amd.com 2009-07-28 12:27:39
# 9728       Ian.Jackson@eu.citrix.com       eu.citrix.com 2009-08-04 10:32:41
# 9729         Christoph.Egger@amd.com             amd.com 2009-08-04 12:33:13
#
#       balance flag  merged emailtype  num_flag_review  num_flag_ack  \
# 0           0   na       0   comment                0             0
# 1           0   na       0   comment                0             0
# 2           0   na       0   comment                0             0
# 3           0   na       0   comment                0             0
# 4           0   na       0   comment                0             0
# 5           0   na       0   comment                0             0
# 6           0   na       0   comment                0             0
# 7           0   na       0   comment                0             0
# 8           0   na       0   comment                0             0
# 9           0   na       0   comment                0             0
# 10          0   na       0   comment                0             0
# 11          0   na       0   comment                0             0
# 12          0   na       0   comment                0             0
# 13          0   na       0   comment                0             0
# 14          0   na       0   comment                0             0
# 15          0   na       0   comment                0             0
# 16          0   na       0   comment                0             0
# 17          0   na       0   comment                0             0
# 18          0   na       0   comment                0             0
# 19          0   na       0   comment                0             0
# 20          0   na       0   comment                0             0
# 21          0   na       0   comment                0             0
# 22          0   na       0   comment                0             0
# 23          0   na       0   comment                0             0
# 24          0   na       0   comment                0             0
# 25          0   na       0   comment                0             0
# 26          0   na       0   comment                0             0
# 27          0   na       0   comment                0             0
# 28          0   na       0   comment                0             0
# 29          0   na       0   comment                0             0
# ...       ...  ...     ...       ...              ...           ...
# 9700        0   na       0   comment                0             0
# 9701        0   na       0   comment                0             0
# 9702        0   na       0   comment                0             0
# 9703        0   na       0   comment                0             0
# 9704        0   na       0   comment                0             0
# 9705        0   na       0   comment                0             0
# 9706        0   na       0   comment                0             0
# 9707        0   na       0   comment                0             0
# 9708        0   na       0   comment                0             0
# 9709        0   na       0   comment                0             0
# 9710        0   na       0   comment                0             0
# 9711        0   na       0   comment                0             0
# 9712        0   na       0   comment                0             0
# 9713        0   na       0   comment                0             0
# 9714        0   na       0   comment                0             0
# 9715        0   na       0   comment                0             0
# 9716        0   na       0   comment                0             0
# 9717        0   na       0   comment                0             0
# 9718        0   na       0   comment                0             0
# 9719        0   na       0   comment                0             0
# 9720        0   na       0   comment                0             0
# 9721        0   na       0   comment                0             0
# 9722        0   na       0   comment                0             0
# 9723        0   na       0   comment                0             0
# 9724        0   na       0   comment                0             0
# 9725        0   na       0   comment                0             0
# 9726        0   na       0   comment                0             0
# 9727        0   na       0   comment                0             0
# 9728        0   na       0   comment                0             0
# 9729        0   na       0   comment                0             0
#
#       num_patch  is_acked  post_ack_comment
# 0             0         0                 1
# 1             0         0                 1
# 2             0         0                 1
# 3             0         0                 1
# 4             0         0                 1
# 5             0         0                 1
# 6             0         0                 1
# 7             0         0                 1
# 8             0         0                 1
# 9             0         0                 1
# 10            0         0                 1
# 11            0         0                 1
# 12            0         0                 1
# 13            0         0                 1
# 14            0         0                 1
# 15            0         0                 1
# 16            0         0                 1
# 17            0         0                 1
# 18            0         0                 1
# 19            0         0                 1
# 20            0         0                 1
# 21            0         0                 1
# 22            0         0                 1
# 23            0         0                 1
# 24            0         0                 1
# 25            0         0                 1
# 26            0         0                 1
# 27            0         0                 1
# 28            0         0                 1
# 29            0         0                 1
# ...         ...       ...               ...
# 9700          0         0                 1
# 9701          0         0                 1
# 9702          0         0                 1
# 9703          0         0                 1
# 9704          0         0                 1
# 9705          0         0                 1
# 9706          0         0                 1
# 9707          0         0                 1
# 9708          0         0                 1
# 9709          0         0                 1
# 9710          0         0                 1
# 9711          0         0                 1
# 9712          0         0                 1
# 9713          0         0                 1
# 9714          0         0                 1
# 9715          0         0                 1
# 9716          0         0                 1
# 9717          0         0                 1
# 9718          0         0                 1
# 9719          0         0                 1
# 9720          0         0                 1
# 9721          0         0                 1
# 9722          0         0                 1
# 9723          0         0                 1
# 9724          0         0                 1
# 9725          0         0                 1
# 9726          0         0                 1
# 9727          0         0                 1
# 9728          0         0                 1
# 9729          0         0                 1
#
# [9730 rows x 16 columns]

# %%
all_data = pandas.concat([patchseries_df, patches_df, flags_df, comments_df])

# %%
INDEX = 'xen-patchseries-reviewers'

# Adding specific not-analyzed requirements to a couple of fields
mapping = '''
{
  
       "properties":{
           "sender": {
               "type":     "string",
               "index":    "not_analyzed"
           },
           "sender_domain": {
               "type":     "string",
               "index":    "not_analyzed"
           }
           
       }
    
}
'''

#As the mapping does not seem to work, we need to PUT the following:
"""
PUT /xen-patchseries-reviewers/_mapping/patchserie
{
    "properties": {
        "sender" : {
            "type": "string",
            "index": "not_analyzed"
        }
    }
}
"""

# Building the ES connection


es2 = Elasticsearch()
# Creating the index
es2.indices.create(index=INDEX, body=mapping)
# Out:
# {u'_id': u'xen-patchseries-reviewers',
#  u'_index': u'xen-patchseries-reviewers',
#  u'_shards': {u'failed': 0, u'successful': 1, u'total': 2},
#  u'_type': u"'",
#  u'_version': 1,
#  u'created': True}

# %%
columns = all_data.columns.values.tolist()
print columns
uniq_id = 0
bulk_doc = []
for row in all_data.itertuples():
    # Let's insert into ES each tuple found in the dataset
    uniq_id = uniq_id + 1
    doc = to_json(row, columns)
    header = {
        "_index": INDEX,
        "_type": "patchserie",
        "_id": uniq_id,
        "_source": doc
    }
    
    bulk_doc.append(header)
    if uniq_id % 100 == 0:
        #result = es2.bulk(index=INDEX, doc_type='patchserie', body=bulk_doc)
        helpers.bulk(es2, bulk_doc)
        bulk_doc = []
# Out:
# ['patchserie_id', 'patch_id', 'comment_id', 'subject', 'sender', 'sender_domain', 'sent_date', 'balance', 'flag', 'merged', 'emailtype', 'num_flag_review', 'num_flag_ack', 'num_patch', 'is_acked', 'post_ack_comment']
