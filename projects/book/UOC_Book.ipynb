# %% [markdown]
# Introduction
# ============
#
# Introduction to libre software communities
#
# * People, people and people
# * Infrastructure publicly available (typical infrastructure)
# * Analyzing that publicly available infrastructure (list of data sources)
# * Quantitative studies of interest about libre software communities (activity, community and process)
# * Risks of participating in libre software communities
#
#
# Libre software communities are about people. People with a common mission to accomplish specific goals. Developers, maintainers, designers, lawyers and a long list of roles that help libre software communities to reach their goal.
#
# And all of these members use a common infrastructure, in most of the cases opened to third parties, that aims at attracting more and more people to participate with them. Indeed transparency is an important fact of libre software communities, where all of the information is public to anyone interested in the project.
#
# And thanks to this publicly available infrastructure, it is possible to understand the software development process of these communities. Usual infrastructure used by libre software communities takes advantage of:
#
# * Source code management systems: Git, Mercurial or SVN are some examples of typical infrastructure used for versioning systems. This infrastructure helps to manage development activity.
# * Mailing lists: Channels of communication that leave traces of information such as mboxes.
# * Asynchronous communication: IRC channels or Slack.
# * Issue tracking systems: Bugzilla, Jira, GitHub tracker.
# * Code review systems: Gerrit, home developed applications, Phabricator.
# * Wikis
#
#
#
# Measuring Activity and Community
# ================================
#
# * Usual and basic metrics to measure activity per data source
# * Usual and basic metrics to measure community per data source
#  * Available filters (merges, bots, repositories, companies, type of files, etc
# * Specific example: filtering commits by type of analysis
# * Specific example: the onion model and activity per timezone
#
# Introduction to metrics of activity and community
# -------------------------------------------------
#
# There are several options to measure basic activity. OpenHub or the basic GitHub metrics are some examples. However, there are usual limitations in the retrieval process given by the API and limitations in how to use the retrieved datasets. In addition, those analysis are only focused on versioning systems or at most adding information from ticketing systems.
#
# However, it is possible to analyze a lot of more data sources offered by open source projects: mailing lists, code review systems or asynchronous channels of communication are some examples.
#
# The following is a not complete list for illustration purposes of the basic pieces of information that can be obtained from each of the data sources. This can be seen as a way to understand in a first glimpse the activity and community around a community of developers:
#
# * Versioning systems such as Git, SVN or Mercurial:
#  * Commits
#  * Authors
#  * Files
#  * Added or removed lines
#  * Repositories
#
# * Ticketing systems such as Bugzilla, Jira or GitHub tracker:
#  * Opened and closed issues
#  * People opening and closing issues
#  * People participating in the discussiong within the issues
#  * People changing the status of the issues
#  * Time to close an issue
#  * Trackers
#
# * Mailing lists:
#  * Total emails sent to the mailing list
#  * People participating in the discussions
#  * Number of discussions (threads)
#  * People initiating threads
#  * People participating in each thread
#  * Lenght of the threads
#
# * Code review systems:
#  * Patchsets sent to the review system
#  * People sending those patchsets to the system
#  * People reviewing those patchsets
#  * People participating in the review process
#  * Time to close a review
#
#
# *TODO: Introduction to GrimoireLib and examples of code of how to retrieve those basic metrics.*
#
# Advanced studies
# ----------------
#
# On top of this, each of the previous metrics may be merged to conform new and more advanced metrics.
#
# * Onion Model
#
# An example of this could be entitled as "onion" model (reference: http://firstmonday.org/article/view/1207/1127) that helps to understand the basics of the effort division in open source communities. This analysis is based on counting commits and characterizing developers based on such activity.
#
# *TODO: Example of analysis of the onion model thanks to GrimoireLib.*
#
# * Main threads
#
# The analysis of threads may show interesting facts. There are several points of view to determine when a thread is interesting for the community of is a flame. However, from a more quantitative point of view, this can be determined by the number of people participating in the discussion or the number of emails that are taking part of such thread.
#
# *TODO: Example of analysis of the main threads*
#
#
# * Recommended lectures
#  * The social structure of free and open source software development. Kevin Crowston and James Howison. First Monday. Volume 10, Number 2 - 7 February 2005. http://firstmonday.org/article/view/1207/1127
#  * Producing Open Source: How to Run a Successful Free Software Project. Chapter 3: Technical Infrastructure http://producingoss.com/en/technical-infrastructure.html . 2005. Karl Fogel
#
#
# * Exercises
#  * Have a look at the several OpenStac
#
# ###
#
#
# Process
# =======
#
# * What does process mean?
# * Measuring process in libre software communities
# * Specific example: Gerrit and time to merge
#
#
# Basic Metrics
# -------------
#
# * Time to merge
# * BMI
# * Time waiting for a reviewer or a submitter action
